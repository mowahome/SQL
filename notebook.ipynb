# %% [markdown]
# # Intermediate SQL
#
# Here you can access every table used in the course. To access each table, you will need to specify the `cinema` schema in your queries (e.g., `cinema.reviews` for the `reviews` table.

# %% [markdown]
# ## Take Notes
#
# Add notes about the concepts you've learned and SQL cells with queries you want to keep.

# %% [markdown]
# _Add your notes here_

# %%
-- Add your own queries here
SELECT *
FROM cinema.reviews
LIMIT 5

# %% [markdown]
# ## Explore Datasets
# Use the `descriptions`, `films`, `people`, `reviews`, and `roles` tables to explore the data and practice your skills!
# - Which titles in the `reviews` table have an IMDB score higher than 8.5?
# - Select all titles from Germany released after 2010 from the `films` table.
# - Calculate a count of all movies by country using the `films` table.

# %%
SELECT DISTINCT(title)
FROM cinema.films, cinema.reviews
WHERE imdb_score>8.5;
# Out:
#                                          title
# 0                                 The Forsaken
# 1                             The Benchwarmers
# 2                Atlas Shrugged II: The Strike
# 3                                  The Fighter
# 4     The Princess Diaries 2: Royal Engagement
# ...                                        ...
# 4839                          Mighty Joe Young
# 4840                            White Oleander
# 4841                        The King of Najayo
# 4842                                  The Help
# 4843                                   Quartet
#
# [4844 rows x 1 columns]

# %%
SELECT title
FROM cinema.films
WHERE (language='German' AND release_year>2010);
# Out:
#              title
# 0  Buen Día, Ramón

# %%
SELECT country, COUNT(*)
FROM cinema.films
GROUP BY country;
# Out:
#            country  count
# 0     Soviet Union      1
# 1        Indonesia      1
# 2            Italy     22
# 3         Cameroon      1
# 4   Czech Republic      3
# ..             ...    ...
# 60         Belgium      4
# 61          Mexico     17
# 62          Poland      3
# 63          Taiwan      2
# 64        Thailand      5
#
# [65 rows x 2 columns]
